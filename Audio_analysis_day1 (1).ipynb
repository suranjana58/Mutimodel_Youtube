# %%
pip install moviepy opencv-python librosa
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install moviepy librosa matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from moviepy.editor import VideoFileClip
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load the video clip
video_clip = VideoFileClip("/Users/suranjanachowdhury/Downloads/sample1.mp4")

# Extract audio from the video
audio_array, sample_rate = librosa.load(video_clip.audio.filename, mono=True)

# Plot the waveform
plt.figure(figsize=(12, 4))
librosa.display.waveshow(audio_array, sr=sample_rate)
plt.title('Waveform')
plt.show()

# %%
# Compute MFCCs
mfccs = librosa.feature.mfcc(y=audio_array, sr=sample_rate, n_mfcc=13)

# Display the MFCCs
plt.figure(figsize=(12, 4))
librosa.display.specshow(mfccs, x_axis='time')
plt.title('MFCCs')
plt.colorbar()
plt.show()

# %%
# Compute the spectrogram
spectrogram = librosa.feature.melspectrogram(y=audio_array, sr=sample_rate)

# Plot the spectrogram
plt.figure(figsize=(12, 8))
librosa.display.specshow(librosa.power_to_db(spectrogram, ref=np.max), y_axis='mel', x_axis='time')
plt.title('Spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.show()
